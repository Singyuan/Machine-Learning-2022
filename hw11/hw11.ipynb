# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# If there are any questions, please contact mlta-2022-spring@googlegroups.com

# %% [markdown]
# # Readme
#
# In homework 11, you will need to implement Domain Adversarial Training in Transfer Learning. As shown in the bottom left part of the figure.
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# >
#
# ## Scenario and Why Domain Adversarial Training
# Now we have labeled source data and unlabeled target data, where source data might be relavent to the target data. We now want to train a model with source data only and test it on target data.
#
# What problem might occur if we do so? After we have learned Anomaly Detection, we now know that if we test the model with an abnormal data that have never appeared in source data, our trained model is likely to result in poor performance since it is not familiar with the abnormal data.
#
# For example, we have a model that contains Feature Extractor and Classifier:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# When the model is trained with source data, the feature extractor
# will extract meaningful features since it is familiar with the distribution of it.It could be seen in the following figure that the blue dots, which is the distribution of source data, has already been clustered into different clusters. Therefore, the Classifier can predict the label based on these clusters.
#
# However, when test on the target data, the Feature Extractor will not be able to extract meaningful features that follow the distribution of the source feature distribution, which result in the classifier learned for the source domain will not be able to apply to the target domain.
#
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
#
# Based on the above problems, DaNN approaches build mappings between the source (training-time) and the target (test-time) domains, so that the classifier learned for the source domain can also be applied to the target domain, when composed with the learned mapping between domains.
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# In DaNN, the authors added a Domain Classifier, which is a deep discriminatively-trained classifeir in the training framework to distinguish the data from different domain by the features extracted by the feature extractor. As the training progresses, the approach promotes a domain classifier that discriminates between the source and the target domains and a feature extractor that can extractor features that are discriminative for the main learning task on the source domain and indiscriminate with respect to the shift between the domains.
#
#
# The feature extractor are likely to outperform the domain classifier as its input are generated by the feature extractor and that the task of domain classification and label classification are not conflict.
#
# This method leads to the emergence of features that are domain-invariant and on the same feature distribution.

# %% [markdown]
# # Data Introduce
#
# Our task contains source data: real photos, and target data: hand-drawn graffiti.
#
# We are going to train the model with the photos and the labels, and try to predict what the labels are for hand-drawn graffiti.
#
# The data could be downloaded [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip). The code below is for data downloading and visualization.
#
# Note that: **The source and target data are all balanced data, you can make use of this information.**

# %%
# !nvidia-smi
# Out:
# Tue May 24 05:44:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    43W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Download dataset
# %%capture
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
# !unzip real_or_drawing.zip

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# When we graffiti, we usually draw the outline only, therefore we can perform edge detection processing on the source data to make it more similar to the target data.
#
#
# ## Canny Edge Detection
# The implementation of Canny Edge Detection is as follow.
# The algorithm will not be describe thoroughly here.  If you are interested, please refer to the wiki or [here](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# We only need two parameters to implement Canny Edge Detection with CV2:  `low_threshold` and `high_threshold`.
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# Simply put, when the edge value exceeds the high_threshold, we determine it as an edge. If the edge value is only above low_threshold, we will then determine whether it is an edge or not.
#
# Let's implement it on the source data.

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # Data Process
#
#
# The data is suitible for `torchvision.ImageFolder`. You can create a dataset with `torchvision.ImageFolder`. Details for image augmentation please refer to the comments in the following codes.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
 
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
 
source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
 
source_dataset = ImageFolder('real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('real_or_drawing/test_data', transform=target_transform)
 
source_dataloader = DataLoader(source_dataset, batch_size=64, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Model
#
# Feature Extractor: Classic VGG-like architecture
#
# Label Predictor / Domain Classifier: Linear models.

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# Here we use Adam as our optimizor.

# %%
from torch.optim.lr_scheduler import StepLR
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())

scheduler_F = StepLR(optimizer_F, step_size=400, gamma=0.5)
scheduler_C = StepLR(optimizer_C, step_size=400, gamma=0.5)
scheduler_D = StepLR(optimizer_D, step_size=400, gamma=0.5)

# %% [markdown]
# ## Lambda setting
# P. 21 in https://arxiv.org/pdf/1505.07818.pdf</br>
# The $\gamma$ is set 10.

# %%
import matplotlib.pyplot as plt

N_EPOCH = 1600

x = [i for i in range(N_EPOCH)]
lb = [2 / (1 + np.exp(-10.0 * i / N_EPOCH)) - 1 for i in range(N_EPOCH)]
plt.plot(x, lb)
plt.show()

# %% [markdown]
# # Start Training
#
#
# ## DaNN Implementation
#
# In the original paper, Gradient Reversal Layer is used.
# Feature Extractor, Label Predictor, and Domain Classifier are all trained at the same time. In this code, we train Domain Classifier first, and then train our Feature Extractor (same concept as Generator and Discriminator training process in GAN).
#
# ## Reminder
# * Lambda, which controls the domain adversarial loss, is adaptive in the original paper. You can refer to [the original work](https://arxiv.org/pdf/1505.07818.pdf) . Here lambda is set to 0.1.
# * We do not have the label to target data, you can only evaluate your model by uploading your result to kaggle.:)

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        
        # Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss+= loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss+= loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()

        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r')

    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

# train 200 epochs
for epoch in range(N_EPOCH):
    # train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=0.1)
    lb = 2 / (1 + np.exp(-10.0 * epoch / N_EPOCH)) - 1
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=lb)
    
    scheduler_F.step()
    scheduler_C.step()
    scheduler_D.step()
    
    torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
    torch.save(label_predictor.state_dict(), f'predictor_model.bin')
    
    if epoch%200 == 0:
        torch.save(feature_extractor.state_dict(), f'extractor_model_{epoch}.bin')
        print(f'[{epoch+1}/{N_EPOCH}]: Save the middle stage model')

    if epoch == 3:
        torch.save(feature_extractor.state_dict(), f'extractor_early_model.bin')
        print(f'[{epoch+1}/{N_EPOCH}]: Save the early stage model')

    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}, lr {:.4f}, lamb {:.4f}'.format(epoch, train_D_loss, train_F_loss, train_acc, scheduler_F.get_last_lr()[0], lb))
# Out:
# [1/1600]: Save the middle stage model
# epoch   0: train D loss: 0.2527, train F loss: 1.9433, acc 0.2878, lr 0.0010, lamb 0.0000
# epoch   1: train D loss: 0.2750, train F loss: 1.6360, acc 0.4028, lr 0.0010, lamb 0.0031
# epoch   2: train D loss: 0.2798, train F loss: 1.5119, acc 0.4616, lr 0.0010, lamb 0.0062
# [4/1600]: Save the early stage model
# epoch   3: train D loss: 0.2847, train F loss: 1.4503, acc 0.4932, lr 0.0010, lamb 0.0094
# epoch   4: train D loss: 0.3484, train F loss: 1.3546, acc 0.5190, lr 0.0010, lamb 0.0125
# epoch   5: train D loss: 0.2907, train F loss: 1.3227, acc 0.5380, lr 0.0010, lamb 0.0156
# epoch   6: train D loss: 0.3091, train F loss: 1.2542, acc 0.5640, lr 0.0010, lamb 0.0187
# epoch   7: train D loss: 0.3259, train F loss: 1.2072, acc 0.5738, lr 0.0010, lamb 0.0219
# epoch   8: train D loss: 0.3104, train F loss: 1.1733, acc 0.5880, lr 0.0010, lamb 0.0250
# epoch   9: train D loss: 0.3109, train F loss: 1.1573, acc 0.5884, lr 0.0010, lamb 0.0281
# epoch  10: train D loss: 0.3043, train F loss: 1.1067, acc 0.6180, lr 0.0010, lamb 0.0312
# epoch  11: train D loss: 0.3466, train F loss: 1.1094, acc 0.6138, lr 0.0010, lamb 0.0344
# epoch  12: train D loss: 0.3656, train F loss: 1.0639, acc 0.6330, lr 0.0010, lamb 0.0375
# epoch  13: train D loss: 0.3457, train F loss: 0.9814, acc 0.6440, lr 0.0010, lamb 0.0406
# epoch  14: train D loss: 0.3579, train F loss: 0.9821, acc 0.6568, lr 0.0010, lamb 0.0437
# epoch  15: train D loss: 0.3721, train F loss: 0.9384, acc 0.6674, lr 0.0010, lamb 0.0468
# epoch  16: train D loss: 0.3519, train F loss: 0.9208, acc 0.6708, lr 0.0010, lamb 0.0500
# epoch  17: train D loss: 0.3945, train F loss: 0.8824, acc 0.6844, lr 0.0010, lamb 0.0531
# epoch  18: train D loss: 0.3923, train F loss: 0.8663, acc 0.7050, lr 0.0010, lamb 0.0562
# epoch  19: train D loss: 0.3768, train F loss: 0.8601, acc 0.7012, lr 0.0010, lamb 0.0593
# epoch  20: train D loss: 0.3775, train F loss: 0.7658, acc 0.7244, lr 0.0010, lamb 0.0624
# epoch  21: train D loss: 0.3894, train F loss: 0.7852, acc 0.7162, lr 0.0010, lamb 0.0655
# epoch  22: train D loss: 0.3572, train F loss: 0.7238, acc 0.7378, lr 0.0010, lamb 0.0686
# epoch  23: train D loss: 0.3684, train F loss: 0.6831, acc 0.7582, lr 0.0010, lamb 0.0718
# epoch  24: train D loss: 0.3961, train F loss: 0.6906, acc 0.7458, lr 0.0010, lamb 0.0749
# epoch  25: train D loss: 0.3925, train F loss: 0.6366, acc 0.7756, lr 0.0010, lamb 0.0780
# epoch  26: train D loss: 0.4041, train F loss: 0.6281, acc 0.7736, lr 0.0010, lamb 0.0811
# epoch  27: train D loss: 0.3857, train F loss: 0.6021, acc 0.7802, lr 0.0010, lamb 0.0842
# epoch  28: train D loss: 0.3979, train F loss: 0.5800, acc 0.7856, lr 0.0010, lamb 0.0873
# epoch  29: train D loss: 0.3975, train F loss: 0.5231, acc 0.8094, lr 0.0010, lamb 0.0904
# epoch  30: train D loss: 0.4002, train F loss: 0.5104, acc 0.8130, lr 0.0010, lamb 0.0935
# epoch  31: train D loss: 0.3766, train F loss: 0.4862, acc 0.8158, lr 0.0010, lamb 0.0966
# epoch  32: train D loss: 0.4418, train F loss: 0.4300, acc 0.8378, lr 0.0010, lamb 0.0997
# epoch  33: train D loss: 0.4108, train F loss: 0.4559, acc 0.8280, lr 0.0010, lamb 0.1028
# epoch  34: train D loss: 0.3974, train F loss: 0.3980, acc 0.8524, lr 0.0010, lamb 0.1059
# epoch  35: train D loss: 0.3958, train F loss: 0.3725, acc 0.8558, lr 0.0010, lamb 0.1089
# epoch  36: train D loss: 0.4421, train F loss: 0.3567, acc 0.8538, lr 0.0010, lamb 0.1120
# epoch  37: train D loss: 0.4166, train F loss: 0.3624, acc 0.8612, lr 0.0010, lamb 0.1151
# epoch  38: train D loss: 0.4197, train F loss: 0.3507, acc 0.8640, lr 0.0010, lamb 0.1182
# epoch  39: train D loss: 0.4107, train F loss: 0.3400, acc 0.8706, lr 0.0010, lamb 0.1213
# epoch  40: train D loss: 0.4353, train F loss: 0.3028, acc 0.8810, lr 0.0010, lamb 0.1244
# epoch  41: train D loss: 0.4287, train F loss: 0.3206, acc 0.8778, lr 0.0010, lamb 0.1274
# epoch  42: train D loss: 0.4139, train F loss: 0.3148, acc 0.8784, lr 0.0010, lamb 0.1305
# epoch  43: train D loss: 0.4242, train F loss: 0.2901, acc 0.8818, lr 0.0010, lamb 0.1336
# epoch  44: train D loss: 0.4304, train F loss: 0.2632, acc 0.8922, lr 0.0010, lamb 0.1366
# epoch  45: train D loss: 0.4198, train F loss: 0.2365, acc 0.8970, lr 0.0010, lamb 0.1397
# epoch  46: train D loss: 0.4092, train F loss: 0.2056, acc 0.9092, lr 0.0010, lamb 0.1428
# epoch  47: train D loss: 0.3983, train F loss: 0.2067, acc 0.9098, lr 0.0010, lamb 0.1458
# epoch  48: train D loss: 0.4278, train F loss: 0.1922, acc 0.9130, lr 0.0010, lamb 0.1489
# epoch  49: train D loss: 0.4340, train F loss: 0.1767, acc 0.9160, lr 0.0010, lamb 0.1519
# epoch  50: train D loss: 0.4603, train F loss: 0.1827, acc 0.9144, lr 0.0010, lamb 0.1550
# epoch  51: train D loss: 0.4178, train F loss: 0.1622, acc 0.9250, lr 0.0010, lamb 0.1580
# epoch  52: train D loss: 0.4509, train F loss: 0.1438, acc 0.9292, lr 0.0010, lamb 0.1611
# epoch  53: train D loss: 0.4359, train F loss: 0.1264, acc 0.9336, lr 0.0010, lamb 0.1641
# epoch  54: train D loss: 0.4427, train F loss: 0.1347, acc 0.9332, lr 0.0010, lamb 0.1672
# epoch  55: train D loss: 0.4484, train F loss: 0.1370, acc 0.9290, lr 0.0010, lamb 0.1702
# epoch  56: train D loss: 0.4450, train F loss: 0.1119, acc 0.9392, lr 0.0010, lamb 0.1732
# epoch  57: train D loss: 0.4428, train F loss: 0.1599, acc 0.9230, lr 0.0010, lamb 0.1763
# epoch  58: train D loss: 0.4705, train F loss: 0.1051, acc 0.9390, lr 0.0010, lamb 0.1793
# epoch  59: train D loss: 0.4575, train F loss: 0.1175, acc 0.9350, lr 0.0010, lamb 0.1823
# epoch  60: train D loss: 0.4788, train F loss: 0.1471, acc 0.9224, lr 0.0010, lamb 0.1853
# epoch  61: train D loss: 0.4699, train F loss: 0.1166, acc 0.9302, lr 0.0010, lamb 0.1883
# epoch  62: train D loss: 0.4783, train F loss: 0.1279, acc 0.9284, lr 0.0010, lamb 0.1914
# epoch  63: train D loss: 0.4743, train F loss: 0.0594, acc 0.9476, lr 0.0010, lamb 0.1944
# epoch  64: train D loss: 0.4795, train F loss: 0.1009, acc 0.9384, lr 0.0010, lamb 0.1974
# epoch  65: train D loss: 0.4727, train F loss: 0.0966, acc 0.9372, lr 0.0010, lamb 0.2004
# epoch  66: train D loss: 0.4939, train F loss: 0.1035, acc 0.9356, lr 0.0010, lamb 0.2034
# epoch  67: train D loss: 0.4753, train F loss: 0.0618, acc 0.9486, lr 0.0010, lamb 0.2064
# epoch  68: train D loss: 0.4892, train F loss: 0.0596, acc 0.9476, lr 0.0010, lamb 0.2094
# epoch  69: train D loss: 0.4687, train F loss: 0.0261, acc 0.9598, lr 0.0010, lamb 0.2123
# epoch  70: train D loss: 0.4821, train F loss: 0.0419, acc 0.9516, lr 0.0010, lamb 0.2153
# epoch  71: train D loss: 0.4801, train F loss: 0.0314, acc 0.9566, lr 0.0010, lamb 0.2183
# epoch  72: train D loss: 0.5044, train F loss: 0.0352, acc 0.9524, lr 0.0010, lamb 0.2213
# epoch  73: train D loss: 0.4705, train F loss: 0.0433, acc 0.9504, lr 0.0010, lamb 0.2242
# epoch  74: train D loss: 0.5138, train F loss: 0.0313, acc 0.9542, lr 0.0010, lamb 0.2272
# epoch  75: train D loss: 0.4914, train F loss: 0.0220, acc 0.9584, lr 0.0010, lamb 0.2302
# epoch  76: train D loss: 0.5038, train F loss: 0.0362, acc 0.9480, lr 0.0010, lamb 0.2331
# epoch  77: train D loss: 0.4979, train F loss: 0.0337, acc 0.9528, lr 0.0010, lamb 0.2361
# epoch  78: train D loss: 0.5025, train F loss: 0.0008, acc 0.9630, lr 0.0010, lamb 0.2390
# epoch  79: train D loss: 0.5022, train F loss: 0.0113, acc 0.9550, lr 0.0010, lamb 0.2420
# epoch  80: train D loss: 0.5189, train F loss: 0.0211, acc 0.9528, lr 0.0010, lamb 0.2449
# epoch  81: train D loss: 0.5175, train F loss: 0.0430, acc 0.9432, lr 0.0010, lamb 0.2479
# epoch  82: train D loss: 0.5124, train F loss: 0.0119, acc 0.9556, lr 0.0010, lamb 0.2508
# epoch  83: train D loss: 0.5016, train F loss: 0.0079, acc 0.9602, lr 0.0010, lamb 0.2537
# epoch  84: train D loss: 0.5310, train F loss: -0.0093, acc 0.9586, lr 0.0010, lamb 0.2566
# epoch  85: train D loss: 0.5286, train F loss: -0.0204, acc 0.9640, lr 0.0010, lamb 0.2595
# epoch  86: train D loss: 0.5278, train F loss: 0.0099, acc 0.9556, lr 0.0010, lamb 0.2625
# epoch  87: train D loss: 0.5206, train F loss: 0.0093, acc 0.9540, lr 0.0010, lamb 0.2654
# epoch  88: train D loss: 0.5148, train F loss: -0.0307, acc 0.9664, lr 0.0010, lamb 0.2683
# epoch  89: train D loss: 0.5425, train F loss: -0.0301, acc 0.9630, lr 0.0010, lamb 0.2712
# epoch  90: train D loss: 0.5623, train F loss: -0.0217, acc 0.9570, lr 0.0010, lamb 0.2741
# epoch  91: train D loss: 0.5369, train F loss: -0.0279, acc 0.9646, lr 0.0010, lamb 0.2769
# epoch  92: train D loss: 0.5454, train F loss: -0.0314, acc 0.9612, lr 0.0010, lamb 0.2798
# epoch  93: train D loss: 0.5215, train F loss: -0.0392, acc 0.9670, lr 0.0010, lamb 0.2827
# epoch  94: train D loss: 0.5628, train F loss: -0.0114, acc 0.9508, lr 0.0010, lamb 0.2856
# epoch  95: train D loss: 0.5404, train F loss: -0.0498, acc 0.9666, lr 0.0010, lamb 0.2885
# epoch  96: train D loss: 0.5507, train F loss: -0.0431, acc 0.9630, lr 0.0010, lamb 0.2913
# epoch  97: train D loss: 0.5521, train F loss: -0.0505, acc 0.9664, lr 0.0010, lamb 0.2942
# epoch  98: train D loss: 0.5626, train F loss: -0.0469, acc 0.9614, lr 0.0010, lamb 0.2970
# epoch  99: train D loss: 0.5554, train F loss: -0.0699, acc 0.9694, lr 0.0010, lamb 0.2999
# epoch 100: train D loss: 0.5604, train F loss: -0.0798, acc 0.9726, lr 0.0010, lamb 0.3027
# epoch 101: train D loss: 0.5623, train F loss: -0.0732, acc 0.9696, lr 0.0010, lamb 0.3055
# epoch 102: train D loss: 0.5412, train F loss: -0.0572, acc 0.9676, lr 0.0010, lamb 0.3084
# epoch 103: train D loss: 0.5727, train F loss: -0.0464, acc 0.9588, lr 0.0010, lamb 0.3112
# epoch 104: train D loss: 0.5654, train F loss: -0.0365, acc 0.9528, lr 0.0010, lamb 0.3140
# epoch 105: train D loss: 0.5607, train F loss: -0.0642, acc 0.9652, lr 0.0010, lamb 0.3168
# epoch 106: train D loss: 0.5574, train F loss: -0.0196, acc 0.9492, lr 0.0010, lamb 0.3196
# epoch 107: train D loss: 0.5678, train F loss: -0.0741, acc 0.9664, lr 0.0010, lamb 0.3224
# epoch 108: train D loss: 0.5618, train F loss: -0.0537, acc 0.9596, lr 0.0010, lamb 0.3252
# epoch 109: train D loss: 0.5680, train F loss: -0.0842, acc 0.9700, lr 0.0010, lamb 0.3280
# epoch 110: train D loss: 0.5750, train F loss: -0.0876, acc 0.9692, lr 0.0010, lamb 0.3308
# epoch 111: train D loss: 0.5818, train F loss: -0.0750, acc 0.9638, lr 0.0010, lamb 0.3336
# epoch 112: train D loss: 0.5697, train F loss: -0.1029, acc 0.9718, lr 0.0010, lamb 0.3364
# epoch 113: train D loss: 0.5681, train F loss: -0.1054, acc 0.9730, lr 0.0010, lamb 0.3391
# epoch 114: train D loss: 0.5715, train F loss: -0.0917, acc 0.9680, lr 0.0010, lamb 0.3419
# epoch 115: train D loss: 0.5651, train F loss: -0.0980, acc 0.9706, lr 0.0010, lamb 0.3447
# epoch 116: train D loss: 0.5562, train F loss: -0.1013, acc 0.9748, lr 0.0010, lamb 0.3474
# epoch 117: train D loss: 0.5930, train F loss: -0.1151, acc 0.9702, lr 0.0010, lamb 0.3502
# epoch 118: train D loss: 0.5601, train F loss: -0.1025, acc 0.9732, lr 0.0010, lamb 0.3529
# epoch 119: train D loss: 0.5648, train F loss: -0.1017, acc 0.9710, lr 0.0010, lamb 0.3556
# epoch 120: train D loss: 0.5965, train F loss: -0.0845, acc 0.9598, lr 0.0010, lamb 0.3584
# epoch 121: train D loss: 0.5783, train F loss: -0.0592, acc 0.9550, lr 0.0010, lamb 0.3611
# epoch 122: train D loss: 0.5742, train F loss: -0.0926, acc 0.9630, lr 0.0010, lamb 0.3638
# epoch 123: train D loss: 0.5645, train F loss: -0.1193, acc 0.9730, lr 0.0010, lamb 0.3665
# epoch 124: train D loss: 0.5905, train F loss: -0.0710, acc 0.9568, lr 0.0010, lamb 0.3692
# epoch 125: train D loss: 0.5727, train F loss: -0.1265, acc 0.9712, lr 0.0010, lamb 0.3719
# epoch 126: train D loss: 0.5838, train F loss: -0.1249, acc 0.9698, lr 0.0010, lamb 0.3746
# epoch 127: train D loss: 0.5806, train F loss: -0.1141, acc 0.9660, lr 0.0010, lamb 0.3773
# epoch 128: train D loss: 0.5685, train F loss: -0.1280, acc 0.9726, lr 0.0010, lamb 0.3799
# epoch 129: train D loss: 0.5884, train F loss: -0.1338, acc 0.9710, lr 0.0010, lamb 0.3826
# epoch 130: train D loss: 0.5989, train F loss: -0.1222, acc 0.9670, lr 0.0010, lamb 0.3853
# epoch 131: train D loss: 0.5745, train F loss: -0.1351, acc 0.9744, lr 0.0010, lamb 0.3879
# epoch 132: train D loss: 0.5719, train F loss: -0.1572, acc 0.9804, lr 0.0010, lamb 0.3906
# epoch 133: train D loss: 0.5881, train F loss: -0.1449, acc 0.9728, lr 0.0010, lamb 0.3932
# epoch 134: train D loss: 0.5954, train F loss: -0.1218, acc 0.9664, lr 0.0010, lamb 0.3959
# epoch 135: train D loss: 0.6134, train F loss: -0.1625, acc 0.9772, lr 0.0010, lamb 0.3985
# epoch 136: train D loss: 0.5883, train F loss: -0.1492, acc 0.9750, lr 0.0010, lamb 0.4011
# epoch 137: train D loss: 0.5920, train F loss: -0.1560, acc 0.9736, lr 0.0010, lamb 0.4038
# epoch 138: train D loss: 0.6017, train F loss: -0.1584, acc 0.9720, lr 0.0010, lamb 0.4064
# epoch 139: train D loss: 0.6055, train F loss: -0.1402, acc 0.9654, lr 0.0010, lamb 0.4090
# epoch 140: train D loss: 0.6056, train F loss: -0.1595, acc 0.9714, lr 0.0010, lamb 0.4116
# epoch 141: train D loss: 0.5842, train F loss: -0.1678, acc 0.9758, lr 0.0010, lamb 0.4142
# epoch 142: train D loss: 0.6057, train F loss: -0.1691, acc 0.9754, lr 0.0010, lamb 0.4167
# epoch 143: train D loss: 0.5918, train F loss: -0.1654, acc 0.9756, lr 0.0010, lamb 0.4193
# epoch 144: train D loss: 0.5793, train F loss: -0.1583, acc 0.9762, lr 0.0010, lamb 0.4219
# epoch 145: train D loss: 0.5976, train F loss: -0.1340, acc 0.9626, lr 0.0010, lamb 0.4245
# epoch 146: train D loss: 0.6003, train F loss: -0.1793, acc 0.9788, lr 0.0010, lamb 0.4270
# epoch 147: train D loss: 0.6127, train F loss: -0.1699, acc 0.9730, lr 0.0010, lamb 0.4296
# epoch 148: train D loss: 0.6040, train F loss: -0.1856, acc 0.9758, lr 0.0010, lamb 0.4321
# epoch 149: train D loss: 0.6221, train F loss: -0.1852, acc 0.9772, lr 0.0010, lamb 0.4347
# epoch 150: train D loss: 0.6284, train F loss: -0.1553, acc 0.9624, lr 0.0010, lamb 0.4372
# epoch 151: train D loss: 0.5997, train F loss: -0.1796, acc 0.9736, lr 0.0010, lamb 0.4397
# epoch 152: train D loss: 0.6076, train F loss: -0.1931, acc 0.9774, lr 0.0010, lamb 0.4422
# epoch 153: train D loss: 0.5940, train F loss: -0.1717, acc 0.9716, lr 0.0010, lamb 0.4447
# epoch 154: train D loss: 0.6150, train F loss: -0.1860, acc 0.9736, lr 0.0010, lamb 0.4472
# epoch 155: train D loss: 0.5873, train F loss: -0.1837, acc 0.9770, lr 0.0010, lamb 0.4497
# epoch 156: train D loss: 0.6172, train F loss: -0.1985, acc 0.9750, lr 0.0010, lamb 0.4522
# epoch 157: train D loss: 0.6102, train F loss: -0.2054, acc 0.9780, lr 0.0010, lamb 0.4547
# epoch 158: train D loss: 0.6043, train F loss: -0.1673, acc 0.9682, lr 0.0010, lamb 0.4572
# epoch 159: train D loss: 0.6076, train F loss: -0.1976, acc 0.9768, lr 0.0010, lamb 0.4597
# epoch 160: train D loss: 0.6002, train F loss: -0.1868, acc 0.9736, lr 0.0010, lamb 0.4621
# epoch 161: train D loss: 0.6149, train F loss: -0.1982, acc 0.9758, lr 0.0010, lamb 0.4646
# epoch 162: train D loss: 0.6034, train F loss: -0.1689, acc 0.9670, lr 0.0010, lamb 0.4670
# epoch 163: train D loss: 0.6180, train F loss: -0.2033, acc 0.9746, lr 0.0010, lamb 0.4695
# epoch 164: train D loss: 0.6084, train F loss: -0.1922, acc 0.9734, lr 0.0010, lamb 0.4719
# epoch 165: train D loss: 0.6148, train F loss: -0.1839, acc 0.9666, lr 0.0010, lamb 0.4743
# epoch 166: train D loss: 0.5971, train F loss: -0.1881, acc 0.9722, lr 0.0010, lamb 0.4767
# epoch 167: train D loss: 0.6052, train F loss: -0.1214, acc 0.9526, lr 0.0010, lamb 0.4791
# epoch 168: train D loss: 0.6134, train F loss: -0.1907, acc 0.9684, lr 0.0010, lamb 0.4815
# epoch 169: train D loss: 0.5970, train F loss: -0.1788, acc 0.9680, lr 0.0010, lamb 0.4839
# epoch 170: train D loss: 0.6094, train F loss: -0.2034, acc 0.9706, lr 0.0010, lamb 0.4863
# epoch 171: train D loss: 0.5983, train F loss: -0.2120, acc 0.9778, lr 0.0010, lamb 0.4887
# epoch 172: train D loss: 0.5934, train F loss: -0.1969, acc 0.9728, lr 0.0010, lamb 0.4911
# epoch 173: train D loss: 0.6222, train F loss: -0.2290, acc 0.9762, lr 0.0010, lamb 0.4935
# epoch 174: train D loss: 0.5948, train F loss: -0.2202, acc 0.9780, lr 0.0010, lamb 0.4958
# epoch 175: train D loss: 0.6025, train F loss: -0.2267, acc 0.9784, lr 0.0010, lamb 0.4982
# epoch 176: train D loss: 0.6094, train F loss: -0.2318, acc 0.9776, lr 0.0010, lamb 0.5005
# epoch 177: train D loss: 0.6213, train F loss: -0.2369, acc 0.9762, lr 0.0010, lamb 0.5029
# epoch 178: train D loss: 0.6061, train F loss: -0.2279, acc 0.9762, lr 0.0010, lamb 0.5052
# epoch 179: train D loss: 0.6163, train F loss: -0.2267, acc 0.9754, lr 0.0010, lamb 0.5075
# epoch 180: train D loss: 0.6146, train F loss: -0.2444, acc 0.9796, lr 0.0010, lamb 0.5098
# epoch 181: train D loss: 0.6278, train F loss: -0.2506, acc 0.9766, lr 0.0010, lamb 0.5121
# epoch 182: train D loss: 0.6264, train F loss: -0.2014, acc 0.9656, lr 0.0010, lamb 0.5144
# epoch 183: train D loss: 0.6304, train F loss: -0.2109, acc 0.9642, lr 0.0010, lamb 0.5167
# epoch 184: train D loss: 0.6178, train F loss: -0.2154, acc 0.9674, lr 0.0010, lamb 0.5190
# epoch 185: train D loss: 0.6153, train F loss: -0.2303, acc 0.9722, lr 0.0010, lamb 0.5213
# epoch 186: train D loss: 0.6045, train F loss: -0.2196, acc 0.9720, lr 0.0010, lamb 0.5236
# epoch 187: train D loss: 0.6219, train F loss: -0.2588, acc 0.9788, lr 0.0010, lamb 0.5258
# epoch 188: train D loss: 0.6122, train F loss: -0.2517, acc 0.9788, lr 0.0010, lamb 0.5281
# epoch 189: train D loss: 0.6200, train F loss: -0.2513, acc 0.9772, lr 0.0010, lamb 0.5303
# epoch 190: train D loss: 0.6207, train F loss: -0.2658, acc 0.9802, lr 0.0010, lamb 0.5326
# epoch 191: train D loss: 0.6221, train F loss: -0.2621, acc 0.9802, lr 0.0010, lamb 0.5348
# epoch 192: train D loss: 0.6058, train F loss: -0.2574, acc 0.9804, lr 0.0010, lamb 0.5370
# epoch 193: train D loss: 0.6136, train F loss: -0.2487, acc 0.9788, lr 0.0010, lamb 0.5393
# epoch 194: train D loss: 0.6171, train F loss: -0.2705, acc 0.9816, lr 0.0010, lamb 0.5415
# epoch 195: train D loss: 0.6315, train F loss: -0.2691, acc 0.9756, lr 0.0010, lamb 0.5437
# epoch 196: train D loss: 0.6377, train F loss: -0.2627, acc 0.9760, lr 0.0010, lamb 0.5459
# epoch 197: train D loss: 0.6332, train F loss: -0.2728, acc 0.9786, lr 0.0010, lamb 0.5481
# epoch 198: train D loss: 0.6227, train F loss: -0.2702, acc 0.9794, lr 0.0010, lamb 0.5503
# epoch 199: train D loss: 0.6227, train F loss: -0.2739, acc 0.9782, lr 0.0010, lamb 0.5524
# [201/1600]: Save the middle stage model
# epoch 200: train D loss: 0.6175, train F loss: -0.2754, acc 0.9792, lr 0.0010, lamb 0.5546
# epoch 201: train D loss: 0.6199, train F loss: -0.2741, acc 0.9798, lr 0.0010, lamb 0.5568
# epoch 202: train D loss: 0.6240, train F loss: -0.2874, acc 0.9810, lr 0.0010, lamb 0.5589
# epoch 203: train D loss: 0.6253, train F loss: -0.2696, acc 0.9778, lr 0.0010, lamb 0.5611
# epoch 204: train D loss: 0.6370, train F loss: -0.2326, acc 0.9648, lr 0.0010, lamb 0.5632
# epoch 205: train D loss: 0.6303, train F loss: -0.2478, acc 0.9678, lr 0.0010, lamb 0.5653
# epoch 206: train D loss: 0.6160, train F loss: -0.2641, acc 0.9756, lr 0.0010, lamb 0.5674
# epoch 207: train D loss: 0.6258, train F loss: -0.2633, acc 0.9712, lr 0.0010, lamb 0.5696
# epoch 208: train D loss: 0.6289, train F loss: -0.2738, acc 0.9778, lr 0.0010, lamb 0.5717
# epoch 209: train D loss: 0.6214, train F loss: -0.2956, acc 0.9820, lr 0.0010, lamb 0.5738
# epoch 210: train D loss: 0.6287, train F loss: -0.2954, acc 0.9802, lr 0.0010, lamb 0.5759
# epoch 211: train D loss: 0.6218, train F loss: -0.2871, acc 0.9796, lr 0.0010, lamb 0.5779
# epoch 212: train D loss: 0.6114, train F loss: -0.2802, acc 0.9772, lr 0.0010, lamb 0.5800
# epoch 213: train D loss: 0.6435, train F loss: -0.3038, acc 0.9798, lr 0.0010, lamb 0.5821
# epoch 214: train D loss: 0.6270, train F loss: -0.2970, acc 0.9802, lr 0.0010, lamb 0.5842
# epoch 215: train D loss: 0.6222, train F loss: -0.2845, acc 0.9754, lr 0.0010, lamb 0.5862
# epoch 216: train D loss: 0.6366, train F loss: -0.2885, acc 0.9782, lr 0.0010, lamb 0.5883
# epoch 217: train D loss: 0.6219, train F loss: -0.2650, acc 0.9720, lr 0.0010, lamb 0.5903
# epoch 218: train D loss: 0.6437, train F loss: -0.3174, acc 0.9826, lr 0.0010, lamb 0.5923
# epoch 219: train D loss: 0.6347, train F loss: -0.3125, acc 0.9800, lr 0.0010, lamb 0.5944
# epoch 220: train D loss: 0.6357, train F loss: -0.3076, acc 0.9782, lr 0.0010, lamb 0.5964
# epoch 221: train D loss: 0.6225, train F loss: -0.3056, acc 0.9802, lr 0.0010, lamb 0.5984
# epoch 222: train D loss: 0.6232, train F loss: -0.2948, acc 0.9780, lr 0.0010, lamb 0.6004
# epoch 223: train D loss: 0.6306, train F loss: -0.2776, acc 0.9726, lr 0.0010, lamb 0.6024
# epoch 224: train D loss: 0.6405, train F loss: -0.3103, acc 0.9766, lr 0.0010, lamb 0.6044
# epoch 225: train D loss: 0.6341, train F loss: -0.3041, acc 0.9758, lr 0.0010, lamb 0.6063
# epoch 226: train D loss: 0.6685, train F loss: -0.3455, acc 0.9800, lr 0.0010, lamb 0.6083
# epoch 227: train D loss: 0.6419, train F loss: -0.3231, acc 0.9778, lr 0.0010, lamb 0.6103
# epoch 228: train D loss: 0.6247, train F loss: -0.3292, acc 0.9848, lr 0.0010, lamb 0.6122
# epoch 229: train D loss: 0.6340, train F loss: -0.3219, acc 0.9820, lr 0.0010, lamb 0.6142
# epoch 230: train D loss: 0.6380, train F loss: -0.3138, acc 0.9754, lr 0.0010, lamb 0.6161
# epoch 231: train D loss: 0.6367, train F loss: -0.3315, acc 0.9786, lr 0.0010, lamb 0.6181
# epoch 232: train D loss: 0.6403, train F loss: -0.3307, acc 0.9800, lr 0.0010, lamb 0.6200
# epoch 233: train D loss: 0.6386, train F loss: -0.3297, acc 0.9816, lr 0.0010, lamb 0.6219
# epoch 234: train D loss: 0.6412, train F loss: -0.3398, acc 0.9834, lr 0.0010, lamb 0.6238
# epoch 235: train D loss: 0.6388, train F loss: -0.3331, acc 0.9810, lr 0.0010, lamb 0.6257
# epoch 236: train D loss: 0.6246, train F loss: -0.3231, acc 0.9806, lr 0.0010, lamb 0.6276
# epoch 237: train D loss: 0.6309, train F loss: -0.3228, acc 0.9822, lr 0.0010, lamb 0.6295
# epoch 238: train D loss: 0.6399, train F loss: -0.3203, acc 0.9784, lr 0.0010, lamb 0.6314
# epoch 239: train D loss: 0.6342, train F loss: -0.3103, acc 0.9748, lr 0.0010, lamb 0.6333
# epoch 240: train D loss: 0.6421, train F loss: -0.3294, acc 0.9782, lr 0.0010, lamb 0.6351
# epoch 241: train D loss: 0.6363, train F loss: -0.3299, acc 0.9752, lr 0.0010, lamb 0.6370
# epoch 242: train D loss: 0.6284, train F loss: -0.3307, acc 0.9772, lr 0.0010, lamb 0.6389
# epoch 243: train D loss: 0.6332, train F loss: -0.3362, acc 0.9790, lr 0.0010, lamb 0.6407
# epoch 244: train D loss: 0.6340, train F loss: -0.3410, acc 0.9804, lr 0.0010, lamb 0.6425
# epoch 245: train D loss: 0.6436, train F loss: -0.3418, acc 0.9784, lr 0.0010, lamb 0.6444
# epoch 246: train D loss: 0.6474, train F loss: -0.3324, acc 0.9740, lr 0.0010, lamb 0.6462
# epoch 247: train D loss: 0.6338, train F loss: -0.3529, acc 0.9822, lr 0.0010, lamb 0.6480
# epoch 248: train D loss: 0.6327, train F loss: -0.3558, acc 0.9850, lr 0.0010, lamb 0.6498
# epoch 249: train D loss: 0.6323, train F loss: -0.3457, acc 0.9796, lr 0.0010, lamb 0.6516
# epoch 250: train D loss: 0.6435, train F loss: -0.3636, acc 0.9824, lr 0.0010, lamb 0.6534
# epoch 251: train D loss: 0.6391, train F loss: -0.3523, acc 0.9812, lr 0.0010, lamb 0.6552
# epoch 252: train D loss: 0.6391, train F loss: -0.3556, acc 0.9808, lr 0.0010, lamb 0.6570
# epoch 253: train D loss: 0.6388, train F loss: -0.3552, acc 0.9806, lr 0.0010, lamb 0.6588
# epoch 254: train D loss: 0.6373, train F loss: -0.3482, acc 0.9820, lr 0.0010, lamb 0.6605
# epoch 255: train D loss: 0.6391, train F loss: -0.3014, acc 0.9692, lr 0.0010, lamb 0.6623
# epoch 256: train D loss: 0.6432, train F loss: -0.3555, acc 0.9786, lr 0.0010, lamb 0.6640
# epoch 257: train D loss: 0.6406, train F loss: -0.3607, acc 0.9798, lr 0.0010, lamb 0.6658
# epoch 258: train D loss: 0.6262, train F loss: -0.3489, acc 0.9798, lr 0.0010, lamb 0.6675
# epoch 259: train D loss: 0.6498, train F loss: -0.3691, acc 0.9816, lr 0.0010, lamb 0.6692
# epoch 260: train D loss: 0.6349, train F loss: -0.3591, acc 0.9774, lr 0.0010, lamb 0.6710
# epoch 261: train D loss: 0.6418, train F loss: -0.3686, acc 0.9832, lr 0.0010, lamb 0.6727
# epoch 262: train D loss: 0.6366, train F loss: -0.3792, acc 0.9850, lr 0.0010, lamb 0.6744
# epoch 263: train D loss: 0.6457, train F loss: -0.3788, acc 0.9828, lr 0.0010, lamb 0.6761
# epoch 264: train D loss: 0.6438, train F loss: -0.3763, acc 0.9836, lr 0.0010, lamb 0.6778
# epoch 265: train D loss: 0.6425, train F loss: -0.3696, acc 0.9814, lr 0.0010, lamb 0.6795
# epoch 266: train D loss: 0.6488, train F loss: -0.3614, acc 0.9752, lr 0.0010, lamb 0.6811
# epoch 267: train D loss: 0.6420, train F loss: -0.3774, acc 0.9824, lr 0.0010, lamb 0.6828
# epoch 268: train D loss: 0.6361, train F loss: -0.3728, acc 0.9810, lr 0.0010, lamb 0.6845
# epoch 269: train D loss: 0.6341, train F loss: -0.3781, acc 0.9836, lr 0.0010, lamb 0.6861
# epoch 270: train D loss: 0.6317, train F loss: -0.3655, acc 0.9804, lr 0.0010, lamb 0.6878
# epoch 271: train D loss: 0.6375, train F loss: -0.3752, acc 0.9836, lr 0.0010, lamb 0.6894
# epoch 272: train D loss: 0.6479, train F loss: -0.3774, acc 0.9806, lr 0.0010, lamb 0.6911
# epoch 273: train D loss: 0.6382, train F loss: -0.3808, acc 0.9794, lr 0.0010, lamb 0.6927
# epoch 274: train D loss: 0.6383, train F loss: -0.3759, acc 0.9814, lr 0.0010, lamb 0.6943
# epoch 275: train D loss: 0.6429, train F loss: -0.3798, acc 0.9814, lr 0.0010, lamb 0.6959
# epoch 276: train D loss: 0.6479, train F loss: -0.3976, acc 0.9856, lr 0.0010, lamb 0.6975
# epoch 277: train D loss: 0.6408, train F loss: -0.3926, acc 0.9826, lr 0.0010, lamb 0.6991
# epoch 278: train D loss: 0.6489, train F loss: -0.3742, acc 0.9794, lr 0.0010, lamb 0.7007
# epoch 279: train D loss: 0.6521, train F loss: -0.3891, acc 0.9802, lr 0.0010, lamb 0.7023
# epoch 280: train D loss: 0.6422, train F loss: -0.3924, acc 0.9824, lr 0.0010, lamb 0.7039
# epoch 281: train D loss: 0.6568, train F loss: -0.3972, acc 0.9830, lr 0.0010, lamb 0.7055
# epoch 282: train D loss: 0.6454, train F loss: -0.3855, acc 0.9810, lr 0.0010, lamb 0.7070
# epoch 283: train D loss: 0.6511, train F loss: -0.3557, acc 0.9702, lr 0.0010, lamb 0.7086
# epoch 284: train D loss: 0.6443, train F loss: -0.3635, acc 0.9738, lr 0.0010, lamb 0.7102
# epoch 285: train D loss: 0.6337, train F loss: -0.3849, acc 0.9806, lr 0.0010, lamb 0.7117
# epoch 286: train D loss: 0.6353, train F loss: -0.3895, acc 0.9816, lr 0.0010, lamb 0.7132
# epoch 287: train D loss: 0.6356, train F loss: -0.4009, acc 0.9828, lr 0.0010, lamb 0.7148
# epoch 288: train D loss: 0.6382, train F loss: -0.3924, acc 0.9828, lr 0.0010, lamb 0.7163
# epoch 289: train D loss: 0.6412, train F loss: -0.3835, acc 0.9780, lr 0.0010, lamb 0.7178
# epoch 290: train D loss: 0.6514, train F loss: -0.4053, acc 0.9814, lr 0.0010, lamb 0.7193
# epoch 291: train D loss: 0.6533, train F loss: -0.4048, acc 0.9810, lr 0.0010, lamb 0.7208
# epoch 292: train D loss: 0.6469, train F loss: -0.3938, acc 0.9750, lr 0.0010, lamb 0.7223
# epoch 293: train D loss: 0.6395, train F loss: -0.3891, acc 0.9830, lr 0.0010, lamb 0.7238
# epoch 294: train D loss: 0.6500, train F loss: -0.3926, acc 0.9768, lr 0.0010, lamb 0.7253
# epoch 295: train D loss: 0.6443, train F loss: -0.4053, acc 0.9820, lr 0.0010, lamb 0.7268
# epoch 296: train D loss: 0.6387, train F loss: -0.4056, acc 0.9826, lr 0.0010, lamb 0.7283
# epoch 297: train D loss: 0.6443, train F loss: -0.4095, acc 0.9844, lr 0.0010, lamb 0.7297
# epoch 298: train D loss: 0.6377, train F loss: -0.4085, acc 0.9844, lr 0.0010, lamb 0.7312
# epoch 299: train D loss: 0.6542, train F loss: -0.4083, acc 0.9780, lr 0.0010, lamb 0.7326
# epoch 300: train D loss: 0.6402, train F loss: -0.4097, acc 0.9822, lr 0.0010, lamb 0.7341
# epoch 301: train D loss: 0.6397, train F loss: -0.4010, acc 0.9792, lr 0.0010, lamb 0.7355
# epoch 302: train D loss: 0.6549, train F loss: -0.4298, acc 0.9852, lr 0.0010, lamb 0.7369
# epoch 303: train D loss: 0.6526, train F loss: -0.4224, acc 0.9826, lr 0.0010, lamb 0.7384
# epoch 304: train D loss: 0.6509, train F loss: -0.4236, acc 0.9844, lr 0.0010, lamb 0.7398
# epoch 305: train D loss: 0.6457, train F loss: -0.4103, acc 0.9802, lr 0.0010, lamb 0.7412
# epoch 306: train D loss: 0.6471, train F loss: -0.4183, acc 0.9832, lr 0.0010, lamb 0.7426
# epoch 307: train D loss: 0.6480, train F loss: -0.4220, acc 0.9828, lr 0.0010, lamb 0.7440
# epoch 308: train D loss: 0.6500, train F loss: -0.4158, acc 0.9804, lr 0.0010, lamb 0.7454
# epoch 309: train D loss: 0.6457, train F loss: -0.3936, acc 0.9752, lr 0.0010, lamb 0.7468
# epoch 310: train D loss: 0.6543, train F loss: -0.3877, acc 0.9704, lr 0.0010, lamb 0.7482
# epoch 311: train D loss: 0.6440, train F loss: -0.4222, acc 0.9832, lr 0.0010, lamb 0.7495
# epoch 312: train D loss: 0.6451, train F loss: -0.4243, acc 0.9820, lr 0.0010, lamb 0.7509
# epoch 313: train D loss: 0.6432, train F loss: -0.4209, acc 0.9824, lr 0.0010, lamb 0.7523
# epoch 314: train D loss: 0.6329, train F loss: -0.4146, acc 0.9830, lr 0.0010, lamb 0.7536
# epoch 315: train D loss: 0.6406, train F loss: -0.4300, acc 0.9862, lr 0.0010, lamb 0.7550
# epoch 316: train D loss: 0.6552, train F loss: -0.4432, acc 0.9846, lr 0.0010, lamb 0.7563
# epoch 317: train D loss: 0.6437, train F loss: -0.4167, acc 0.9816, lr 0.0010, lamb 0.7576
# epoch 318: train D loss: 0.6543, train F loss: -0.4435, acc 0.9836, lr 0.0010, lamb 0.7590
# epoch 319: train D loss: 0.6511, train F loss: -0.4463, acc 0.9860, lr 0.0010, lamb 0.7603
# epoch 320: train D loss: 0.6472, train F loss: -0.4351, acc 0.9838, lr 0.0010, lamb 0.7616
# epoch 321: train D loss: 0.6523, train F loss: -0.4405, acc 0.9838, lr 0.0010, lamb 0.7629
# epoch 322: train D loss: 0.6562, train F loss: -0.4380, acc 0.9808, lr 0.0010, lamb 0.7642
# epoch 323: train D loss: 0.6546, train F loss: -0.4306, acc 0.9804, lr 0.0010, lamb 0.7655
# epoch 324: train D loss: 0.6512, train F loss: -0.4420, acc 0.9808, lr 0.0010, lamb 0.7668
# epoch 325: train D loss: 0.6587, train F loss: -0.4476, acc 0.9822, lr 0.0010, lamb 0.7681
# epoch 326: train D loss: 0.6531, train F loss: -0.4504, acc 0.9828, lr 0.0010, lamb 0.7694
# epoch 327: train D loss: 0.6493, train F loss: -0.4444, acc 0.9838, lr 0.0010, lamb 0.7706
# epoch 328: train D loss: 0.6581, train F loss: -0.4508, acc 0.9832, lr 0.0010, lamb 0.7719
# epoch 329: train D loss: 0.6604, train F loss: -0.4463, acc 0.9800, lr 0.0010, lamb 0.7732
# epoch 330: train D loss: 0.6483, train F loss: -0.4397, acc 0.9824, lr 0.0010, lamb 0.7744
# epoch 331: train D loss: 0.6645, train F loss: -0.4605, acc 0.9842, lr 0.0010, lamb 0.7757
# epoch 332: train D loss: 0.6489, train F loss: -0.4352, acc 0.9800, lr 0.0010, lamb 0.7769
# epoch 333: train D loss: 0.6485, train F loss: -0.4481, acc 0.9812, lr 0.0010, lamb 0.7781
# epoch 334: train D loss: 0.6507, train F loss: -0.4475, acc 0.9832, lr 0.0010, lamb 0.7794
# epoch 335: train D loss: 0.6409, train F loss: -0.4349, acc 0.9828, lr 0.0010, lamb 0.7806
# epoch 336: train D loss: 0.6642, train F loss: -0.4615, acc 0.9838, lr 0.0010, lamb 0.7818
# epoch 337: train D loss: 0.6508, train F loss: -0.4623, acc 0.9850, lr 0.0010, lamb 0.7830
# epoch 338: train D loss: 0.6554, train F loss: -0.4510, acc 0.9808, lr 0.0010, lamb 0.7842
# epoch 339: train D loss: 0.6520, train F loss: -0.4664, acc 0.9872, lr 0.0010, lamb 0.7854
# epoch 340: train D loss: 0.6621, train F loss: -0.4537, acc 0.9800, lr 0.0010, lamb 0.7866
# epoch 341: train D loss: 0.6459, train F loss: -0.4509, acc 0.9828, lr 0.0010, lamb 0.7878
# epoch 342: train D loss: 0.6562, train F loss: -0.4597, acc 0.9824, lr 0.0010, lamb 0.7890
# epoch 343: train D loss: 0.6462, train F loss: -0.4544, acc 0.9850, lr 0.0010, lamb 0.7902
# epoch 344: train D loss: 0.6605, train F loss: -0.4489, acc 0.9784, lr 0.0010, lamb 0.7913
# epoch 345: train D loss: 0.6549, train F loss: -0.4570, acc 0.9804, lr 0.0010, lamb 0.7925
# epoch 346: train D loss: 0.6520, train F loss: -0.4470, acc 0.9806, lr 0.0010, lamb 0.7937
# epoch 347: train D loss: 0.6454, train F loss: -0.4494, acc 0.9834, lr 0.0010, lamb 0.7948
# epoch 348: train D loss: 0.6570, train F loss: -0.4674, acc 0.9830, lr 0.0010, lamb 0.7960
# epoch 349: train D loss: 0.6477, train F loss: -0.4647, acc 0.9860, lr 0.0010, lamb 0.7971
# epoch 350: train D loss: 0.6536, train F loss: -0.4546, acc 0.9828, lr 0.0010, lamb 0.7982
# epoch 351: train D loss: 0.6554, train F loss: -0.4494, acc 0.9814, lr 0.0010, lamb 0.7994
# epoch 352: train D loss: 0.6458, train F loss: -0.4582, acc 0.9844, lr 0.0010, lamb 0.8005
# epoch 353: train D loss: 0.6489, train F loss: -0.4164, acc 0.9690, lr 0.0010, lamb 0.8016
# epoch 354: train D loss: 0.6357, train F loss: -0.4412, acc 0.9814, lr 0.0010, lamb 0.8027
# epoch 355: train D loss: 0.6521, train F loss: -0.4693, acc 0.9864, lr 0.0010, lamb 0.8038
# epoch 356: train D loss: 0.6531, train F loss: -0.4622, acc 0.9834, lr 0.0010, lamb 0.8049
# epoch 357: train D loss: 0.6599, train F loss: -0.4474, acc 0.9772, lr 0.0010, lamb 0.8060
# epoch 358: train D loss: 0.6561, train F loss: -0.4652, acc 0.9814, lr 0.0010, lamb 0.8071
# epoch 359: train D loss: 0.6418, train F loss: -0.4427, acc 0.9810, lr 0.0010, lamb 0.8082
# epoch 360: train D loss: 0.6495, train F loss: -0.4567, acc 0.9778, lr 0.0010, lamb 0.8093
# epoch 361: train D loss: 0.6528, train F loss: -0.4630, acc 0.9822, lr 0.0010, lamb 0.8104
# epoch 362: train D loss: 0.6581, train F loss: -0.4799, acc 0.9840, lr 0.0010, lamb 0.8114
# epoch 363: train D loss: 0.6468, train F loss: -0.4725, acc 0.9852, lr 0.0010, lamb 0.8125
# epoch 364: train D loss: 0.6434, train F loss: -0.4619, acc 0.9820, lr 0.0010, lamb 0.8136
# epoch 365: train D loss: 0.6567, train F loss: -0.4784, acc 0.9850, lr 0.0010, lamb 0.8146
# epoch 366: train D loss: 0.6510, train F loss: -0.4809, acc 0.9856, lr 0.0010, lamb 0.8157
# epoch 367: train D loss: 0.6490, train F loss: -0.4769, acc 0.9854, lr 0.0010, lamb 0.8167
# epoch 368: train D loss: 0.6542, train F loss: -0.4773, acc 0.9830, lr 0.0010, lamb 0.8178
# epoch 369: train D loss: 0.6535, train F loss: -0.4842, acc 0.9850, lr 0.0010, lamb 0.8188
# epoch 370: train D loss: 0.6557, train F loss: -0.4845, acc 0.9852, lr 0.0010, lamb 0.8198
# epoch 371: train D loss: 0.6546, train F loss: -0.4800, acc 0.9838, lr 0.0010, lamb 0.8208
# epoch 372: train D loss: 0.6582, train F loss: -0.4852, acc 0.9846, lr 0.0010, lamb 0.8219
# epoch 373: train D loss: 0.6567, train F loss: -0.4911, acc 0.9862, lr 0.0010, lamb 0.8229
# epoch 374: train D loss: 0.6596, train F loss: -0.4718, acc 0.9800, lr 0.0010, lamb 0.8239
# epoch 375: train D loss: 0.6500, train F loss: -0.4766, acc 0.9830, lr 0.0010, lamb 0.8249
# epoch 376: train D loss: 0.6434, train F loss: -0.4783, acc 0.9846, lr 0.0010, lamb 0.8259
# epoch 377: train D loss: 0.6562, train F loss: -0.4702, acc 0.9808, lr 0.0010, lamb 0.8269
# epoch 378: train D loss: 0.6540, train F loss: -0.4821, acc 0.9856, lr 0.0010, lamb 0.8278
# epoch 379: train D loss: 0.6588, train F loss: -0.4724, acc 0.9766, lr 0.0010, lamb 0.8288
# epoch 380: train D loss: 0.6532, train F loss: -0.4852, acc 0.9844, lr 0.0010, lamb 0.8298
# epoch 381: train D loss: 0.6543, train F loss: -0.4903, acc 0.9860, lr 0.0010, lamb 0.8308
# epoch 382: train D loss: 0.6511, train F loss: -0.4927, acc 0.9872, lr 0.0010, lamb 0.8317
# epoch 383: train D loss: 0.6564, train F loss: -0.4886, acc 0.9836, lr 0.0010, lamb 0.8327
# epoch 384: train D loss: 0.6547, train F loss: -0.4963, acc 0.9868, lr 0.0010, lamb 0.8337
# epoch 385: train D loss: 0.6609, train F loss: -0.4959, acc 0.9846, lr 0.0010, lamb 0.8346
# epoch 386: train D loss: 0.6585, train F loss: -0.4937, acc 0.9832, lr 0.0010, lamb 0.8356
# epoch 387: train D loss: 0.6549, train F loss: -0.5004, acc 0.9872, lr 0.0010, lamb 0.8365
# epoch 388: train D loss: 0.6654, train F loss: -0.5034, acc 0.9856, lr 0.0010, lamb 0.8374
# epoch 389: train D loss: 0.6637, train F loss: -0.4958, acc 0.9830, lr 0.0010, lamb 0.8384
# epoch 390: train D loss: 0.6624, train F loss: -0.5144, acc 0.9876, lr 0.0010, lamb 0.8393
# epoch 391: train D loss: 0.6531, train F loss: -0.4971, acc 0.9836, lr 0.0010, lamb 0.8402
# epoch 392: train D loss: 0.6532, train F loss: -0.4972, acc 0.9854, lr 0.0010, lamb 0.8411
# epoch 393: train D loss: 0.6565, train F loss: -0.5086, acc 0.9878, lr 0.0010, lamb 0.8420
# epoch 394: train D loss: 0.6525, train F loss: -0.4963, acc 0.9856, lr 0.0010, lamb 0.8429
# epoch 395: train D loss: 0.6606, train F loss: -0.4965, acc 0.9826, lr 0.0010, lamb 0.8438
# epoch 396: train D loss: 0.6544, train F loss: -0.4967, acc 0.9844, lr 0.0010, lamb 0.8447
# epoch 397: train D loss: 0.6600, train F loss: -0.4782, acc 0.9774, lr 0.0010, lamb 0.8456
# epoch 398: train D loss: 0.6594, train F loss: -0.4990, acc 0.9820, lr 0.0010, lamb 0.8465
# epoch 399: train D loss: 0.6584, train F loss: -0.5028, acc 0.9832, lr 0.0005, lamb 0.8474
# [401/1600]: Save the middle stage model
# epoch 400: train D loss: 0.6598, train F loss: -0.5174, acc 0.9882, lr 0.0005, lamb 0.8483
# epoch 401: train D loss: 0.6429, train F loss: -0.5068, acc 0.9906, lr 0.0005, lamb 0.8492
# epoch 402: train D loss: 0.6422, train F loss: -0.5106, acc 0.9898, lr 0.0005, lamb 0.8500
# epoch 403: train D loss: 0.6467, train F loss: -0.5173, acc 0.9920, lr 0.0005, lamb 0.8509
# epoch 404: train D loss: 0.6518, train F loss: -0.5238, acc 0.9912, lr 0.0005, lamb 0.8518
# epoch 405: train D loss: 0.6481, train F loss: -0.5138, acc 0.9898, lr 0.0005, lamb 0.8526
# epoch 406: train D loss: 0.6413, train F loss: -0.5144, acc 0.9892, lr 0.0005, lamb 0.8535
# epoch 407: train D loss: 0.6409, train F loss: -0.5128, acc 0.9896, lr 0.0005, lamb 0.8543
# epoch 408: train D loss: 0.6526, train F loss: -0.5210, acc 0.9898, lr 0.0005, lamb 0.8551
# epoch 409: train D loss: 0.6618, train F loss: -0.5257, acc 0.9874, lr 0.0005, lamb 0.8560
# epoch 410: train D loss: 0.6588, train F loss: -0.5278, acc 0.9874, lr 0.0005, lamb 0.8568
# epoch 411: train D loss: 0.6588, train F loss: -0.5294, acc 0.9888, lr 0.0005, lamb 0.8576
# epoch 412: train D loss: 0.6580, train F loss: -0.5356, acc 0.9922, lr 0.0005, lamb 0.8585
# epoch 413: train D loss: 0.6532, train F loss: -0.5258, acc 0.9900, lr 0.0005, lamb 0.8593
# epoch 414: train D loss: 0.6605, train F loss: -0.5362, acc 0.9904, lr 0.0005, lamb 0.8601
# epoch 415: train D loss: 0.6664, train F loss: -0.5391, acc 0.9894, lr 0.0005, lamb 0.8609
# epoch 416: train D loss: 0.6560, train F loss: -0.5280, acc 0.9896, lr 0.0005, lamb 0.8617
# epoch 417: train D loss: 0.6531, train F loss: -0.5322, acc 0.9908, lr 0.0005, lamb 0.8625
# epoch 418: train D loss: 0.6561, train F loss: -0.5340, acc 0.9896, lr 0.0005, lamb 0.8633
# epoch 419: train D loss: 0.6609, train F loss: -0.5344, acc 0.9892, lr 0.0005, lamb 0.8641
# epoch 420: train D loss: 0.6579, train F loss: -0.5398, acc 0.9910, lr 0.0005, lamb 0.8649
# epoch 421: train D loss: 0.6606, train F loss: -0.5401, acc 0.9906, lr 0.0005, lamb 0.8657
# epoch 422: train D loss: 0.6596, train F loss: -0.5412, acc 0.9910, lr 0.0005, lamb 0.8665
# epoch 423: train D loss: 0.6623, train F loss: -0.5433, acc 0.9922, lr 0.0005, lamb 0.8672
# epoch 424: train D loss: 0.6630, train F loss: -0.5430, acc 0.9898, lr 0.0005, lamb 0.8680
# epoch 425: train D loss: 0.6573, train F loss: -0.5461, acc 0.9920, lr 0.0005, lamb 0.8688
# epoch 426: train D loss: 0.6599, train F loss: -0.5452, acc 0.9926, lr 0.0005, lamb 0.8696
# epoch 427: train D loss: 0.6587, train F loss: -0.5431, acc 0.9922, lr 0.0005, lamb 0.8703
# epoch 428: train D loss: 0.6590, train F loss: -0.5325, acc 0.9882, lr 0.0005, lamb 0.8711
# epoch 429: train D loss: 0.6562, train F loss: -0.5273, acc 0.9900, lr 0.0005, lamb 0.8718
# epoch 430: train D loss: 0.6533, train F loss: -0.5150, acc 0.9844, lr 0.0005, lamb 0.8726
# epoch 431: train D loss: 0.6591, train F loss: -0.5414, acc 0.9904, lr 0.0005, lamb 0.8733
# epoch 432: train D loss: 0.6642, train F loss: -0.5460, acc 0.9906, lr 0.0005, lamb 0.8741
# epoch 433: train D loss: 0.6587, train F loss: -0.5423, acc 0.9902, lr 0.0005, lamb 0.8748
# epoch 434: train D loss: 0.6606, train F loss: -0.5430, acc 0.9896, lr 0.0005, lamb 0.8755
# epoch 435: train D loss: 0.6631, train F loss: -0.5534, acc 0.9918, lr 0.0005, lamb 0.8762
# epoch 436: train D loss: 0.6610, train F loss: -0.5358, acc 0.9898, lr 0.0005, lamb 0.8770
# epoch 437: train D loss: 0.6572, train F loss: -0.5408, acc 0.9904, lr 0.0005, lamb 0.8777
# epoch 438: train D loss: 0.6651, train F loss: -0.5492, acc 0.9900, lr 0.0005, lamb 0.8784
# epoch 439: train D loss: 0.6578, train F loss: -0.5459, acc 0.9908, lr 0.0005, lamb 0.8791
# epoch 440: train D loss: 0.6618, train F loss: -0.5457, acc 0.9880, lr 0.0005, lamb 0.8798
# epoch 441: train D loss: 0.6597, train F loss: -0.5461, acc 0.9898, lr 0.0005, lamb 0.8805
# epoch 442: train D loss: 0.6602, train F loss: -0.5439, acc 0.9888, lr 0.0005, lamb 0.8812
# epoch 443: train D loss: 0.6632, train F loss: -0.5523, acc 0.9896, lr 0.0005, lamb 0.8819
# epoch 444: train D loss: 0.6584, train F loss: -0.5417, acc 0.9908, lr 0.0005, lamb 0.8826
# epoch 445: train D loss: 0.6567, train F loss: -0.5525, acc 0.9930, lr 0.0005, lamb 0.8833
# epoch 446: train D loss: 0.6672, train F loss: -0.5540, acc 0.9910, lr 0.0005, lamb 0.8840
# epoch 447: train D loss: 0.6637, train F loss: -0.5478, acc 0.9904, lr 0.0005, lamb 0.8847
# epoch 448: train D loss: 0.6623, train F loss: -0.5503, acc 0.9882, lr 0.0005, lamb 0.8854
# epoch 449: train D loss: 0.6568, train F loss: -0.5470, acc 0.9916, lr 0.0005, lamb 0.8860
# epoch 450: train D loss: 0.6644, train F loss: -0.5510, acc 0.9904, lr 0.0005, lamb 0.8867
# epoch 451: train D loss: 0.6611, train F loss: -0.5573, acc 0.9924, lr 0.0005, lamb 0.8874
# epoch 452: train D loss: 0.6594, train F loss: -0.5546, acc 0.9916, lr 0.0005, lamb 0.8880
# epoch 453: train D loss: 0.6615, train F loss: -0.5581, acc 0.9918, lr 0.0005, lamb 0.8887
# epoch 454: train D loss: 0.6641, train F loss: -0.5536, acc 0.9892, lr 0.0005, lamb 0.8893
# epoch 455: train D loss: 0.6624, train F loss: -0.5602, acc 0.9912, lr 0.0005, lamb 0.8900
# epoch 456: train D loss: 0.6651, train F loss: -0.5578, acc 0.9888, lr 0.0005, lamb 0.8906
# epoch 457: train D loss: 0.6551, train F loss: -0.5570, acc 0.9928, lr 0.0005, lamb 0.8913
# epoch 458: train D loss: 0.6610, train F loss: -0.5578, acc 0.9908, lr 0.0005, lamb 0.8919
# epoch 459: train D loss: 0.6617, train F loss: -0.5526, acc 0.9896, lr 0.0005, lamb 0.8926
# epoch 460: train D loss: 0.6708, train F loss: -0.5622, acc 0.9894, lr 0.0005, lamb 0.8932
# epoch 461: train D loss: 0.6664, train F loss: -0.5658, acc 0.9908, lr 0.0005, lamb 0.8938
# epoch 462: train D loss: 0.6651, train F loss: -0.5649, acc 0.9904, lr 0.0005, lamb 0.8945
# epoch 463: train D loss: 0.6598, train F loss: -0.5613, acc 0.9920, lr 0.0005, lamb 0.8951
# epoch 464: train D loss: 0.6630, train F loss: -0.5623, acc 0.9902, lr 0.0005, lamb 0.8957
# epoch 465: train D loss: 0.6682, train F loss: -0.5617, acc 0.9876, lr 0.0005, lamb 0.8963
# epoch 466: train D loss: 0.6594, train F loss: -0.5620, acc 0.9916, lr 0.0005, lamb 0.8969
# epoch 467: train D loss: 0.6607, train F loss: -0.5669, acc 0.9928, lr 0.0005, lamb 0.8975
# epoch 468: train D loss: 0.6644, train F loss: -0.5635, acc 0.9910, lr 0.0005, lamb 0.8981
# epoch 469: train D loss: 0.6684, train F loss: -0.5683, acc 0.9902, lr 0.0005, lamb 0.8987
# epoch 470: train D loss: 0.6624, train F loss: -0.5599, acc 0.9902, lr 0.0005, lamb 0.8993
# epoch 471: train D loss: 0.6593, train F loss: -0.5594, acc 0.9902, lr 0.0005, lamb 0.8999
# epoch 472: train D loss: 0.6637, train F loss: -0.5601, acc 0.9896, lr 0.0005, lamb 0.9005
# epoch 473: train D loss: 0.6645, train F loss: -0.5685, acc 0.9918, lr 0.0005, lamb 0.9011
# epoch 474: train D loss: 0.6667, train F loss: -0.5620, acc 0.9888, lr 0.0005, lamb 0.9017
# epoch 475: train D loss: 0.6632, train F loss: -0.5665, acc 0.9906, lr 0.0005, lamb 0.9023
# epoch 476: train D loss: 0.6625, train F loss: -0.5593, acc 0.9902, lr 0.0005, lamb 0.9029
# epoch 477: train D loss: 0.6664, train F loss: -0.5656, acc 0.9920, lr 0.0005, lamb 0.9034
# epoch 478: train D loss: 0.6581, train F loss: -0.5551, acc 0.9884, lr 0.0005, lamb 0.9040
# epoch 479: train D loss: 0.6607, train F loss: -0.5644, acc 0.9918, lr 0.0005, lamb 0.9046
# epoch 480: train D loss: 0.6664, train F loss: -0.5622, acc 0.9876, lr 0.0005, lamb 0.9051
# epoch 481: train D loss: 0.6598, train F loss: -0.5695, acc 0.9914, lr 0.0005, lamb 0.9057
# epoch 482: train D loss: 0.6583, train F loss: -0.5653, acc 0.9910, lr 0.0005, lamb 0.9063
# epoch 483: train D loss: 0.6663, train F loss: -0.5644, acc 0.9908, lr 0.0005, lamb 0.9068
# epoch 484: train D loss: 0.6630, train F loss: -0.5647, acc 0.9896, lr 0.0005, lamb 0.9074
# epoch 485: train D loss: 0.6651, train F loss: -0.5685, acc 0.9902, lr 0.0005, lamb 0.9079
# epoch 486: train D loss: 0.6624, train F loss: -0.5626, acc 0.9906, lr 0.0005, lamb 0.9085
# epoch 487: train D loss: 0.6646, train F loss: -0.5727, acc 0.9898, lr 0.0005, lamb 0.9090
# epoch 488: train D loss: 0.6627, train F loss: -0.5736, acc 0.9922, lr 0.0005, lamb 0.9096
# epoch 489: train D loss: 0.6599, train F loss: -0.5653, acc 0.9894, lr 0.0005, lamb 0.9101
# epoch 490: train D loss: 0.6647, train F loss: -0.5624, acc 0.9876, lr 0.0005, lamb 0.9106
# epoch 491: train D loss: 0.6652, train F loss: -0.5741, acc 0.9920, lr 0.0005, lamb 0.9112
# epoch 492: train D loss: 0.6565, train F loss: -0.5597, acc 0.9880, lr 0.0005, lamb 0.9117
# epoch 493: train D loss: 0.6596, train F loss: -0.5713, acc 0.9918, lr 0.0005, lamb 0.9122
# epoch 494: train D loss: 0.6621, train F loss: -0.5764, acc 0.9922, lr 0.0005, lamb 0.9127
# epoch 495: train D loss: 0.6666, train F loss: -0.5708, acc 0.9904, lr 0.0005, lamb 0.9133
# epoch 496: train D loss: 0.6699, train F loss: -0.5722, acc 0.9890, lr 0.0005, lamb 0.9138
# epoch 497: train D loss: 0.6604, train F loss: -0.5720, acc 0.9914, lr 0.0005, lamb 0.9143
# epoch 498: train D loss: 0.6614, train F loss: -0.5750, acc 0.9910, lr 0.0005, lamb 0.9148
# epoch 499: train D loss: 0.6607, train F loss: -0.5739, acc 0.9902, lr 0.0005, lamb 0.9153
# epoch 500: train D loss: 0.6553, train F loss: -0.5744, acc 0.9930, lr 0.0005, lamb 0.9158
# epoch 501: train D loss: 0.6630, train F loss: -0.5774, acc 0.9916, lr 0.0005, lamb 0.9163
# epoch 502: train D loss: 0.6665, train F loss: -0.5777, acc 0.9916, lr 0.0005, lamb 0.9168
# epoch 503: train D loss: 0.6699, train F loss: -0.5817, acc 0.9902, lr 0.0005, lamb 0.9173
# epoch 504: train D loss: 0.6607, train F loss: -0.5769, acc 0.9914, lr 0.0005, lamb 0.9178
# epoch 505: train D loss: 0.6685, train F loss: -0.5792, acc 0.9898, lr 0.0005, lamb 0.9183
# epoch 506: train D loss: 0.6664, train F loss: -0.5785, acc 0.9894, lr 0.0005, lamb 0.9188
# epoch 507: train D loss: 0.6662, train F loss: -0.5816, acc 0.9904, lr 0.0005, lamb 0.9193
# epoch 508: train D loss: 0.6651, train F loss: -0.5791, acc 0.9902, lr 0.0005, lamb 0.9198
# epoch 509: train D loss: 0.6665, train F loss: -0.5851, acc 0.9918, lr 0.0005, lamb 0.9202
# epoch 510: train D loss: 0.6637, train F loss: -0.5805, acc 0.9914, lr 0.0005, lamb 0.9207
# epoch 511: train D loss: 0.6630, train F loss: -0.5840, acc 0.9930, lr 0.0005, lamb 0.9212
# epoch 512: train D loss: 0.6650, train F loss: -0.5681, acc 0.9868, lr 0.0005, lamb 0.9217
# epoch 513: train D loss: 0.6674, train F loss: -0.5776, acc 0.9900, lr 0.0005, lamb 0.9221
# epoch 514: train D loss: 0.6672, train F loss: -0.5820, acc 0.9916, lr 0.0005, lamb 0.9226
# epoch 515: train D loss: 0.6649, train F loss: -0.5889, acc 0.9940, lr 0.0005, lamb 0.9231
# epoch 516: train D loss: 0.6650, train F loss: -0.5825, acc 0.9910, lr 0.0005, lamb 0.9235
# epoch 517: train D loss: 0.6739, train F loss: -0.5890, acc 0.9896, lr 0.0005, lamb 0.9240
# epoch 518: train D loss: 0.6674, train F loss: -0.5812, acc 0.9900, lr 0.0005, lamb 0.9244
# epoch 519: train D loss: 0.6668, train F loss: -0.5724, acc 0.9890, lr 0.0005, lamb 0.9249
# epoch 520: train D loss: 0.6685, train F loss: -0.5887, acc 0.9914, lr 0.0005, lamb 0.9253
# epoch 521: train D loss: 0.6642, train F loss: -0.5765, acc 0.9888, lr 0.0005, lamb 0.9258
# epoch 522: train D loss: 0.6654, train F loss: -0.5878, acc 0.9914, lr 0.0005, lamb 0.9262
# epoch 523: train D loss: 0.6653, train F loss: -0.5850, acc 0.9908, lr 0.0005, lamb 0.9267
# epoch 524: train D loss: 0.6695, train F loss: -0.5789, acc 0.9882, lr 0.0005, lamb 0.9271
# epoch 525: train D loss: 0.6634, train F loss: -0.5843, acc 0.9906, lr 0.0005, lamb 0.9276
# ...
# epoch 1427: train D loss: 0.6757, train F loss: -0.6638, acc 0.9964, lr 0.0001, lamb 0.9997
# epoch 1428: train D loss: 0.6800, train F loss: -0.6692, acc 0.9970, lr 0.0001, lamb 0.9997
# epoch 1429: train D loss: 0.6774, train F loss: -0.6636, acc 0.9958, lr 0.0001, lamb 0.9997
# epoch 1430: train D loss: 0.6774, train F loss: -0.6613, acc 0.9950, lr 0.0001, lamb 0.9997
# epoch 1431: train D loss: 0.6791, train F loss: -0.6660, acc 0.9954, lr 0.0001, lamb 0.9997
# epoch 1432: train D loss: 0.6773, train F loss: -0.6658, acc 0.9970, lr 0.0001, lamb 0.9997
# epoch 1433: train D loss: 0.6784, train F loss: -0.6649, acc 0.9960, lr 0.0001, lamb 0.9997
# epoch 1434: train D loss: 0.6813, train F loss: -0.6679, acc 0.9958, lr 0.0001, lamb 0.9997
# epoch 1435: train D loss: 0.6778, train F loss: -0.6639, acc 0.9962, lr 0.0001, lamb 0.9997
# epoch 1436: train D loss: 0.6798, train F loss: -0.6681, acc 0.9964, lr 0.0001, lamb 0.9997
# epoch 1437: train D loss: 0.6757, train F loss: -0.6636, acc 0.9966, lr 0.0001, lamb 0.9997
# epoch 1438: train D loss: 0.6782, train F loss: -0.6658, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1439: train D loss: 0.6791, train F loss: -0.6662, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1440: train D loss: 0.6798, train F loss: -0.6633, acc 0.9948, lr 0.0001, lamb 0.9998
# epoch 1441: train D loss: 0.6765, train F loss: -0.6628, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1442: train D loss: 0.6765, train F loss: -0.6626, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1443: train D loss: 0.6807, train F loss: -0.6655, acc 0.9952, lr 0.0001, lamb 0.9998
# epoch 1444: train D loss: 0.6724, train F loss: -0.6566, acc 0.9952, lr 0.0001, lamb 0.9998
# epoch 1445: train D loss: 0.6789, train F loss: -0.6678, acc 0.9966, lr 0.0001, lamb 0.9998
# epoch 1446: train D loss: 0.6798, train F loss: -0.6696, acc 0.9972, lr 0.0001, lamb 0.9998
# epoch 1447: train D loss: 0.6777, train F loss: -0.6640, acc 0.9952, lr 0.0001, lamb 0.9998
# epoch 1448: train D loss: 0.6787, train F loss: -0.6678, acc 0.9968, lr 0.0001, lamb 0.9998
# epoch 1449: train D loss: 0.6793, train F loss: -0.6690, acc 0.9970, lr 0.0001, lamb 0.9998
# epoch 1450: train D loss: 0.6779, train F loss: -0.6606, acc 0.9948, lr 0.0001, lamb 0.9998
# epoch 1451: train D loss: 0.6769, train F loss: -0.6640, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1452: train D loss: 0.6803, train F loss: -0.6701, acc 0.9970, lr 0.0001, lamb 0.9998
# epoch 1453: train D loss: 0.6794, train F loss: -0.6674, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1454: train D loss: 0.6803, train F loss: -0.6681, acc 0.9968, lr 0.0001, lamb 0.9998
# epoch 1455: train D loss: 0.6801, train F loss: -0.6680, acc 0.9966, lr 0.0001, lamb 0.9998
# epoch 1456: train D loss: 0.6755, train F loss: -0.6626, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1457: train D loss: 0.6798, train F loss: -0.6660, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1458: train D loss: 0.6775, train F loss: -0.6632, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1459: train D loss: 0.6796, train F loss: -0.6668, acc 0.9954, lr 0.0001, lamb 0.9998
# epoch 1460: train D loss: 0.6781, train F loss: -0.6647, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1461: train D loss: 0.6787, train F loss: -0.6637, acc 0.9954, lr 0.0001, lamb 0.9998
# epoch 1462: train D loss: 0.6772, train F loss: -0.6639, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1463: train D loss: 0.6792, train F loss: -0.6656, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1464: train D loss: 0.6827, train F loss: -0.6716, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1465: train D loss: 0.6778, train F loss: -0.6666, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1466: train D loss: 0.6751, train F loss: -0.6618, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1467: train D loss: 0.6793, train F loss: -0.6664, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1468: train D loss: 0.6778, train F loss: -0.6627, acc 0.9950, lr 0.0001, lamb 0.9998
# epoch 1469: train D loss: 0.6800, train F loss: -0.6662, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1470: train D loss: 0.6805, train F loss: -0.6683, acc 0.9966, lr 0.0001, lamb 0.9998
# epoch 1471: train D loss: 0.6796, train F loss: -0.6671, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1472: train D loss: 0.6791, train F loss: -0.6653, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1473: train D loss: 0.6800, train F loss: -0.6640, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1474: train D loss: 0.6791, train F loss: -0.6621, acc 0.9946, lr 0.0001, lamb 0.9998
# epoch 1475: train D loss: 0.6805, train F loss: -0.6688, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1476: train D loss: 0.6801, train F loss: -0.6664, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1477: train D loss: 0.6791, train F loss: -0.6671, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1478: train D loss: 0.6782, train F loss: -0.6674, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1479: train D loss: 0.6797, train F loss: -0.6681, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1480: train D loss: 0.6782, train F loss: -0.6627, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1481: train D loss: 0.6774, train F loss: -0.6638, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1482: train D loss: 0.6803, train F loss: -0.6688, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1483: train D loss: 0.6804, train F loss: -0.6708, acc 0.9972, lr 0.0001, lamb 0.9998
# epoch 1484: train D loss: 0.6792, train F loss: -0.6664, acc 0.9966, lr 0.0001, lamb 0.9998
# epoch 1485: train D loss: 0.6781, train F loss: -0.6665, acc 0.9966, lr 0.0001, lamb 0.9998
# epoch 1486: train D loss: 0.6803, train F loss: -0.6672, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1487: train D loss: 0.6777, train F loss: -0.6642, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1488: train D loss: 0.6803, train F loss: -0.6638, acc 0.9954, lr 0.0001, lamb 0.9998
# epoch 1489: train D loss: 0.6807, train F loss: -0.6680, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1490: train D loss: 0.6788, train F loss: -0.6666, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1491: train D loss: 0.6795, train F loss: -0.6651, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1492: train D loss: 0.6819, train F loss: -0.6675, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1493: train D loss: 0.6780, train F loss: -0.6644, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1494: train D loss: 0.6819, train F loss: -0.6675, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1495: train D loss: 0.6791, train F loss: -0.6665, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1496: train D loss: 0.6785, train F loss: -0.6663, acc 0.9968, lr 0.0001, lamb 0.9998
# epoch 1497: train D loss: 0.6781, train F loss: -0.6664, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1498: train D loss: 0.6811, train F loss: -0.6692, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1499: train D loss: 0.6787, train F loss: -0.6674, acc 0.9968, lr 0.0001, lamb 0.9998
# epoch 1500: train D loss: 0.6800, train F loss: -0.6597, acc 0.9954, lr 0.0001, lamb 0.9998
# epoch 1501: train D loss: 0.6790, train F loss: -0.6659, acc 0.9954, lr 0.0001, lamb 0.9998
# epoch 1502: train D loss: 0.6790, train F loss: -0.6672, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1503: train D loss: 0.6777, train F loss: -0.6643, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1504: train D loss: 0.6795, train F loss: -0.6636, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1505: train D loss: 0.6798, train F loss: -0.6662, acc 0.9956, lr 0.0001, lamb 0.9998
# epoch 1506: train D loss: 0.6770, train F loss: -0.6671, acc 0.9972, lr 0.0001, lamb 0.9998
# epoch 1507: train D loss: 0.6785, train F loss: -0.6662, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1508: train D loss: 0.6770, train F loss: -0.6669, acc 0.9970, lr 0.0001, lamb 0.9998
# epoch 1509: train D loss: 0.6782, train F loss: -0.6644, acc 0.9966, lr 0.0001, lamb 0.9998
# epoch 1510: train D loss: 0.6804, train F loss: -0.6648, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1511: train D loss: 0.6785, train F loss: -0.6651, acc 0.9958, lr 0.0001, lamb 0.9998
# epoch 1512: train D loss: 0.6769, train F loss: -0.6630, acc 0.9952, lr 0.0001, lamb 0.9998
# epoch 1513: train D loss: 0.6772, train F loss: -0.6637, acc 0.9964, lr 0.0001, lamb 0.9998
# epoch 1514: train D loss: 0.6785, train F loss: -0.6665, acc 0.9960, lr 0.0001, lamb 0.9998
# epoch 1515: train D loss: 0.6762, train F loss: -0.6574, acc 0.9944, lr 0.0001, lamb 0.9998
# epoch 1516: train D loss: 0.6776, train F loss: -0.6616, acc 0.9948, lr 0.0001, lamb 0.9998
# epoch 1517: train D loss: 0.6768, train F loss: -0.6639, acc 0.9962, lr 0.0001, lamb 0.9998
# epoch 1518: train D loss: 0.6786, train F loss: -0.6681, acc 0.9976, lr 0.0001, lamb 0.9998
# epoch 1519: train D loss: 0.6785, train F loss: -0.6683, acc 0.9972, lr 0.0001, lamb 0.9998
# epoch 1520: train D loss: 0.6801, train F loss: -0.6667, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1521: train D loss: 0.6780, train F loss: -0.6665, acc 0.9966, lr 0.0001, lamb 0.9999
# epoch 1522: train D loss: 0.6772, train F loss: -0.6637, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1523: train D loss: 0.6816, train F loss: -0.6659, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1524: train D loss: 0.6783, train F loss: -0.6658, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1525: train D loss: 0.6784, train F loss: -0.6665, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1526: train D loss: 0.6773, train F loss: -0.6651, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1527: train D loss: 0.6768, train F loss: -0.6629, acc 0.9966, lr 0.0001, lamb 0.9999
# epoch 1528: train D loss: 0.6786, train F loss: -0.6623, acc 0.9948, lr 0.0001, lamb 0.9999
# epoch 1529: train D loss: 0.6777, train F loss: -0.6650, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1530: train D loss: 0.6751, train F loss: -0.6654, acc 0.9976, lr 0.0001, lamb 0.9999
# epoch 1531: train D loss: 0.6791, train F loss: -0.6664, acc 0.9952, lr 0.0001, lamb 0.9999
# epoch 1532: train D loss: 0.6771, train F loss: -0.6631, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1533: train D loss: 0.6781, train F loss: -0.6637, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1534: train D loss: 0.6793, train F loss: -0.6656, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1535: train D loss: 0.6800, train F loss: -0.6651, acc 0.9950, lr 0.0001, lamb 0.9999
# epoch 1536: train D loss: 0.6781, train F loss: -0.6657, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1537: train D loss: 0.6784, train F loss: -0.6634, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1538: train D loss: 0.6760, train F loss: -0.6611, acc 0.9958, lr 0.0001, lamb 0.9999
# epoch 1539: train D loss: 0.6793, train F loss: -0.6646, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1540: train D loss: 0.6776, train F loss: -0.6637, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1541: train D loss: 0.6785, train F loss: -0.6643, acc 0.9968, lr 0.0001, lamb 0.9999
# epoch 1542: train D loss: 0.6770, train F loss: -0.6603, acc 0.9958, lr 0.0001, lamb 0.9999
# epoch 1543: train D loss: 0.6780, train F loss: -0.6666, acc 0.9970, lr 0.0001, lamb 0.9999
# epoch 1544: train D loss: 0.6800, train F loss: -0.6694, acc 0.9970, lr 0.0001, lamb 0.9999
# epoch 1545: train D loss: 0.6782, train F loss: -0.6628, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1546: train D loss: 0.6780, train F loss: -0.6677, acc 0.9970, lr 0.0001, lamb 0.9999
# epoch 1547: train D loss: 0.6771, train F loss: -0.6618, acc 0.9952, lr 0.0001, lamb 0.9999
# epoch 1548: train D loss: 0.6792, train F loss: -0.6646, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1549: train D loss: 0.6780, train F loss: -0.6620, acc 0.9954, lr 0.0001, lamb 0.9999
# epoch 1550: train D loss: 0.6773, train F loss: -0.6619, acc 0.9952, lr 0.0001, lamb 0.9999
# epoch 1551: train D loss: 0.6786, train F loss: -0.6660, acc 0.9966, lr 0.0001, lamb 0.9999
# epoch 1552: train D loss: 0.6787, train F loss: -0.6639, acc 0.9952, lr 0.0001, lamb 0.9999
# epoch 1553: train D loss: 0.6763, train F loss: -0.6620, acc 0.9958, lr 0.0001, lamb 0.9999
# epoch 1554: train D loss: 0.6758, train F loss: -0.6624, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1555: train D loss: 0.6750, train F loss: -0.6618, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1556: train D loss: 0.6793, train F loss: -0.6639, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1557: train D loss: 0.6796, train F loss: -0.6669, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1558: train D loss: 0.6785, train F loss: -0.6635, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1559: train D loss: 0.6774, train F loss: -0.6661, acc 0.9970, lr 0.0001, lamb 0.9999
# epoch 1560: train D loss: 0.6765, train F loss: -0.6629, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1561: train D loss: 0.6771, train F loss: -0.6629, acc 0.9954, lr 0.0001, lamb 0.9999
# epoch 1562: train D loss: 0.6785, train F loss: -0.6671, acc 0.9966, lr 0.0001, lamb 0.9999
# epoch 1563: train D loss: 0.6772, train F loss: -0.6579, acc 0.9946, lr 0.0001, lamb 0.9999
# epoch 1564: train D loss: 0.6772, train F loss: -0.6638, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1565: train D loss: 0.6779, train F loss: -0.6626, acc 0.9944, lr 0.0001, lamb 0.9999
# epoch 1566: train D loss: 0.6791, train F loss: -0.6654, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1567: train D loss: 0.6782, train F loss: -0.6643, acc 0.9952, lr 0.0001, lamb 0.9999
# epoch 1568: train D loss: 0.6763, train F loss: -0.6621, acc 0.9956, lr 0.0001, lamb 0.9999
# epoch 1569: train D loss: 0.6779, train F loss: -0.6653, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1570: train D loss: 0.6765, train F loss: -0.6650, acc 0.9966, lr 0.0001, lamb 0.9999
# epoch 1571: train D loss: 0.6775, train F loss: -0.6640, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1572: train D loss: 0.6777, train F loss: -0.6643, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1573: train D loss: 0.6794, train F loss: -0.6626, acc 0.9948, lr 0.0001, lamb 0.9999
# epoch 1574: train D loss: 0.6777, train F loss: -0.6656, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1575: train D loss: 0.6807, train F loss: -0.6699, acc 0.9970, lr 0.0001, lamb 0.9999
# epoch 1576: train D loss: 0.6762, train F loss: -0.6638, acc 0.9958, lr 0.0001, lamb 0.9999
# epoch 1577: train D loss: 0.6804, train F loss: -0.6688, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1578: train D loss: 0.6783, train F loss: -0.6609, acc 0.9944, lr 0.0001, lamb 0.9999
# epoch 1579: train D loss: 0.6785, train F loss: -0.6672, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1580: train D loss: 0.6805, train F loss: -0.6677, acc 0.9958, lr 0.0001, lamb 0.9999
# epoch 1581: train D loss: 0.6806, train F loss: -0.6626, acc 0.9954, lr 0.0001, lamb 0.9999
# epoch 1582: train D loss: 0.6810, train F loss: -0.6657, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1583: train D loss: 0.6783, train F loss: -0.6650, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1584: train D loss: 0.6789, train F loss: -0.6675, acc 0.9972, lr 0.0001, lamb 0.9999
# epoch 1585: train D loss: 0.6822, train F loss: -0.6657, acc 0.9946, lr 0.0001, lamb 0.9999
# epoch 1586: train D loss: 0.6809, train F loss: -0.6680, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1587: train D loss: 0.6794, train F loss: -0.6669, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1588: train D loss: 0.6806, train F loss: -0.6676, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1589: train D loss: 0.6790, train F loss: -0.6662, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1590: train D loss: 0.6787, train F loss: -0.6662, acc 0.9962, lr 0.0001, lamb 0.9999
# epoch 1591: train D loss: 0.6776, train F loss: -0.6624, acc 0.9954, lr 0.0001, lamb 0.9999
# epoch 1592: train D loss: 0.6787, train F loss: -0.6679, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1593: train D loss: 0.6802, train F loss: -0.6641, acc 0.9952, lr 0.0001, lamb 0.9999
# epoch 1594: train D loss: 0.6782, train F loss: -0.6631, acc 0.9950, lr 0.0001, lamb 0.9999
# epoch 1595: train D loss: 0.6779, train F loss: -0.6658, acc 0.9960, lr 0.0001, lamb 0.9999
# epoch 1596: train D loss: 0.6790, train F loss: -0.6660, acc 0.9958, lr 0.0001, lamb 0.9999
# epoch 1597: train D loss: 0.6789, train F loss: -0.6671, acc 0.9964, lr 0.0001, lamb 0.9999
# epoch 1598: train D loss: 0.6785, train F loss: -0.6683, acc 0.9974, lr 0.0001, lamb 0.9999
# epoch 1599: train D loss: 0.6776, train F loss: -0.6621, acc 0.9956, lr 0.0001, lamb 0.9999

# %% [markdown]
# # Inference
#
# We use pandas to generate our csv file.
#
# BTW, the performance of the model trained for 200 epoches might be unstable. You can train for more epoches for a more stable performance.

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()

    class_logits = label_predictor(feature_extractor(test_data))

    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)

# %% [markdown]
# # Visualization
# We use t-SNE plot to observe the distribution of extracted features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %% [markdown]
# ## Step1: Load checkpoint and evaluate to get extracted features

# %%
source_data, source_label = next(iter(source_dataloader))
# source_data, source_label = next(iter(target_dataloader))
source_data.shape
# Out:
# torch.Size([64, 1, 32, 32])

# %%
feature_extractor = FeatureExtractor().cuda()
checkpoint = torch.load('extractor_model.bin')
feature_extractor.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %%
X_source = np.empty((0,512), float) # initial
Y_source = np.empty((0), int) # initial
for i, (source_data, source_label) in enumerate(source_dataloader):
    feat = feature_extractor(source_data.cuda())
    feat = feat.cpu().detach().numpy()
    X_source = np.append(X_source, feat, axis=0)
    Y_source = np.append(Y_source, source_label.detach().numpy())

# %%
X_target = np.empty((0,512), int) # initial
target_iter = iter(target_dataloader)
cnt = 0
while cnt < 2.0*len(Y_source):
    target_data, target_label = next(target_iter)
    feat = feature_extractor(target_data.cuda())
    feat = feat.cpu().detach().numpy()
    X_target = np.append(X_target, feat, axis=0)
    cnt += len(target_data)

X_all = np.append(X_source, X_target, axis=0)
cmap_source = [0] * len(X_source)
cmap_target = [1] * len(X_target)
cmap_all = cmap_source+cmap_target
cmap_all = np.array(cmap_all)

# %% [markdown]
# ## Step2: Apply t-SNE and normalize

# %%
# process extracted features with t-SNE
X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X_source)

# Normalization the processed features 
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.553s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.131775
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.916718
# [t-SNE] KL divergence after 1000 iterations: 1.731551

# %%
# process extracted features with t-SNE
Xall_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X_all)

# Normalization the processed features 
xall_min, xall_max = Xall_tsne.min(0), Xall_tsne.max(0)
Xall_norm = (Xall_tsne - xall_min) / (xall_max - xall_min)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 15048 samples in 0.006s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 15048 samples in 4.292s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15048
# [t-SNE] Computed conditional probabilities for sample 2000 / 15048
# [t-SNE] Computed conditional probabilities for sample 3000 / 15048
# [t-SNE] Computed conditional probabilities for sample 4000 / 15048
# [t-SNE] Computed conditional probabilities for sample 5000 / 15048
# [t-SNE] Computed conditional probabilities for sample 6000 / 15048
# [t-SNE] Computed conditional probabilities for sample 7000 / 15048
# [t-SNE] Computed conditional probabilities for sample 8000 / 15048
# [t-SNE] Computed conditional probabilities for sample 9000 / 15048
# [t-SNE] Computed conditional probabilities for sample 10000 / 15048
# [t-SNE] Computed conditional probabilities for sample 11000 / 15048
# [t-SNE] Computed conditional probabilities for sample 12000 / 15048
# [t-SNE] Computed conditional probabilities for sample 13000 / 15048
# [t-SNE] Computed conditional probabilities for sample 14000 / 15048
# [t-SNE] Computed conditional probabilities for sample 15000 / 15048
# [t-SNE] Computed conditional probabilities for sample 15048 / 15048
# [t-SNE] Mean sigma: 0.936153
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 88.558952
# [t-SNE] KL divergence after 1000 iterations: 2.333258

# %% [markdown]
# ## Step3: Visualization with matplotlib
# https://moonbooks.org/Articles/How-to-create-a-scatter-plot-with-several-colors-in-matplotlib-/
# https://stackoverflow.com/questions/71256037/control-order-of-tab10-colors-in-colormap

# %%
# Data Visualization
# Use matplotlib to plot the distribution
# The shape of X_norm is (N,2)
plt.figure(figsize=(8,6))
colormap = np.array(plt.cm.tab10.colors)
plt.scatter(X_norm[:, 0], X_norm[:, 1], s=3, c=colormap[Y_source])
# plt.savefig('class-fianl.png')

# %%
# Data Visualization
# Use matplotlib to plot the distribution
# The shape of X_norm is (N,2)
plt.figure(figsize=(8,6))
plt.scatter(Xall_norm[cmap_all==0, 0], Xall_norm[cmap_all==0, 1], s=1, c='r')
plt.scatter(Xall_norm[cmap_all==1, 0], Xall_norm[cmap_all==1, 1], s=1, c='b')
plt.legend(['source', 'target'])
# plt.savefig('source-final.png')

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# If there is any problem related to Domain Adaptation, please email to b08901058@ntu.edu.tw / mlta-2022-spring@googlegroups.com。
